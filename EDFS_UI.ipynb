# %%
from edfs_simulator import EDFS_SIMULATOR

# %%
edfs = EDFS_SIMULATOR()

# %% [markdown]
# edfs is an instance of our emulated distributed file system.
# Type commands like edfs.mkdir('some_dir'), edfs.ls() , ...

# %%
edfs.mkdir("/myfiles")
# Out:
# mkdir: /myfiles: File exists

# %%
edfs.ls()
# Out:
# apple
# myfiles

# %%
edfs.put('Salary_Dataset.csv', '/user/jack', 3)
# Out:
# finished

# %%
edfs.getPartitionLocations('/user/jack/Salary_Dataset')
# Out:
# https://dsci551-7b600-default-rtdb.firebaseio.com/data/user/jack/Salary_Dataset/A0BBL.json
# https://dsci551-7b600-default-rtdb.firebaseio.com/data/user/jack/Salary_Dataset/O43M4.json
# https://dsci551-7b600-default-rtdb.firebaseio.com/data/user/jack/Salary_Dataset/KM1IJ.json
# ['https://dsci551-7b600-default-rtdb.firebaseio.com/data/user/jack/Salary_Dataset/A0BBL.json',
#  'https://dsci551-7b600-default-rtdb.firebaseio.com/data/user/jack/Salary_Dataset/O43M4.json',
#  'https://dsci551-7b600-default-rtdb.firebaseio.com/data/user/jack/Salary_Dataset/KM1IJ.json']

# %%
edfs.readPartition('/user/jack/Salary_Dataset', 1)
# Out:
# https://dsci551-7b600-default-rtdb.firebaseio.com/edfs/user/jack/Salary_Dataset/1.json
# https://dsci551-7b600-default-rtdb.firebaseio.com/data/user/jack/Salary_Dataset/O43M4.json
# [{'Company Name': 'Quinbay', 'Employment Status': 'Full Time', 'Job Roles': 'IOS', 'Job Title': 'Middle IOS Developer', 'Location': 'Bangalore', 'Rating': 4.0, 'Salaries Reported': 1, 'Salary': 1000000}, {'Company Name': 'Koo India', 'Employment Status': 'Full Time', 'Job Roles': 'IOS', 'Job Title': 'Middle IOS Developer', 'Location': 'Bangalore', 'Rating': 3.1, 'Salaries Reported': 1, 'Salary': 1700000}, {'Company Name': 'Dozee', 'Employment Status': 'Full Time', 'Job Roles': 'IOS', 'Job Title': 'Middle IOS Developer', 'Location': 'Bangalore', 'Rating': 4.4, 'Salaries Reported': 1, 'Salary': 800000}, {'Company Name': 'Unizen Technologies', 'Employment Status': 'Full Time', 'Job Roles': 'IOS', 'Job Title': 'Middle IOS Developer', 'Location': 'Bangalore', 'Rating': 3.9, 'Salaries Reported': 1, 'Salary': 600000}, {'Company Name': 'Mentric Group', 'Employment Status': 'Full Time', 'Job Roles': 'IOS', 'Job Title': 'Middle IOS Developer', 'Location': 'Bangalore', 'Rating': 4.4, 'Salaries Reported': 1, 'Salary': 400000}, {'Company Name': 'SwiftAnt IT Solutions', 'Employment Status': 'Full Time', 'Job Roles': 'IOS', 'Job Title': 'Middle IOS Developer', 'Location': 'Bangalore', 'Rating': 4.5, 'Salaries Reported': 1, 'Salary': 300000}, {'Company Name': 'Jiny', 'Employment Status': 'Full Time', 'Job Roles': 'IOS', 'Job Title': 'Middle IOS Developer', 'Location': 'Bangalore', 'Rating': 5.0, 'Salaries Reported': 1, 'Salary': 1500000}, {'Company Name': 'WebWings Global Solutions', 'Employment Status': 'Full Time', 'Job Roles': 'IOS', 'Job Title': 'Middle IOS Developer', 'Location': 'Bangalore', 'Rating': 1.0, 'Salaries Reported': 1, 'Salary': 300000}, {'Company Name': 'i22 Technologies', 'Employment Status': 'Full Time', 'Job Roles': 'IOS', 'Job Title': 'Middle IOS Developer', 'Location': 'Bangalore', 'Rating': 4.3, 'Salaries Reported': 1, 'Salary': 600000}, {'Company Name': 'Healthcius Services', 'Employment Status': 'Full Time', 'Job Roles': 'IOS', 'Job Title': 'Middle IOS Developer', 'Location': 'Bangalore', 'Rating': 3.9, 'Salaries Reported': 1, 'Salary': 1100000}, {'Company Name': 'Infosys', 'Employment Status': 'Full Time', 'Job Roles': 'IOS', 'Job Title': 'IOS Engineer', 'Location': 'Bangalore', 'Rating': 3.3, 'Salaries Reported': 1, 'Salary': 348000}, {'Company Name': "BYJU'S", 'Employment Status': 'Full Time', 'Job Roles': 'IOS', 'Job Title': 'IOS Engineer', 'Location': 'Bangalore', 'Rating': 3.7, 'Salaries Reported': 1, 'Salary': 2400000}, {'Company Name': 'ABC', 'Employment Status': 'Full Time', 'Job Roles': 'IOS', 'Job Title': 'IOS Engineer', 'Location': 'Bangalore', 'Rating': 3.9, 'Salaries Reported': 1, 'Salary': 25344}, {'Company Name': 'Freelancer', 'Employment Status': 'Full Time', 'Job Roles': 'IOS', 'Job Title': 'IOS Engineer', 'Location': 'Bangalore', 'Rating': 4.2, 'Salaries Reported': 1, 'Salary': 1000000}, {'Company Name': 'Quest Global', 'Employment Status': 'Full Time', 'Job Roles': 'IOS', 'Job Title': 'IOS Engineer', 'Location': 'Bangalore', 'Rating': 3.1, 'Salaries Reported': 1, 'Salary': 1000000}, {'Company Name': 'Nous Infosystems', 'Employment Status': 'Full Time', 'Job Roles': 'IOS', 'Job Title': 'IOS Engineer', 'Location': 'Bangalore', 'Rating': 4.0, 'Salaries Reported': 1, 'Salary': 2300000}, {'Company Name': 'Gojek', 'Employment Status': 'Full Time', 'Job Roles': 'IOS', 'Job Title': 'IOS Engineer', 'Location': 'Bangalore', 'Rating': 4.4, 'Salaries Reported': 1, 'Salary': 3400000}, {'Company Name': 'ShareChat', 'Employment Status': 'Full Time', 'Job Roles': 'IOS', 'Job Title': 'IOS Engineer', 'Location': 'Bangalore', 'Rating': 4.4, 'Salaries Reported': 1, 'Salary': 1900000}, {'Company Name': 'Fluper', 'Employment Status': 'Full Time', 'Job Roles': 'IOS', 'Job Title': 'IOS Engineer', 'Location': 'Bangalore', 'Rating': 3.9, 'Salaries Reported': 1, 'Salary': 300000}, {'Company Name': 'Quinbay', 'Employment Status': 'Full Time', 'Job Roles': 'IOS', 'Job Title': 'IOS Engineer', 'Location': 'Bangalore', 'Rating': ...

# %%
edfs.cat('/user/jack/Salary_Dataset.csv')

# %%
edfs.rm('/user/jack/Salary_Dataset.csv')

# %%
edfs.get_avg_salary('/user/jack/Salary_Dataset','IOS Developer')
